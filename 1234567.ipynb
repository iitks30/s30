# %%
import pandas as pd

# %%
event = pd.read_csv('data.csv')

# %%
event.head()
# Out:
#         ID Event Type       Facility Name    County State  \
# 0  2444268   incident                I-80   Passaic    NJ
# 1  2444269   accident  I-87 - NYS Thruway    Orange    NY
# 2  2444270   accident               I-495   Suffolk    NY
# 3  2444273   accident  I-87 - NYS Thruway    Ulster    NY
# 4  2444280   accident       I-87 Northway  Saratoga    NY
#
#               Create Time              Close Time   Latitude  Longitude
# 0  01/01/2019 10:28:48 AM  01/01/2019 10:31:45 AM  40.905799 -74.161079
# 1  01/01/2019 10:47:49 AM  01/01/2019 11:09:05 AM  41.691460 -74.078010
# 2  01/01/2019 01:07:46 PM  01/01/2019 02:02:49 PM  40.818401 -73.063697
# 3  01/01/2019 02:50:46 PM  01/01/2019 04:32:56 PM  42.013360 -73.998992
# 4  01/01/2019 05:11:46 PM  01/01/2019 06:25:44 PM  42.816600 -73.766899

# %%
num_rows = event.shape[0]
num_rows
# Out:
# 27808

# %%
unique = event['State'].value_counts()
# Out:
# NY    19527
# NJ     8253
# CT       26
# PA        2
# Name: State, dtype: int64

# %%
event['Create Time']=pd.to_datetime(event['Create Time'])
event['Close Time']=pd.to_datetime(event['Close Time'])

# %%
event
# Out:
#             ID        Event Type                 Facility Name       County  \
# 0      2444268          incident                          I-80      Passaic
# 1      2444269          accident            I-87 - NYS Thruway       Orange
# 2      2444270          accident                         I-495      Suffolk
# 3      2444273          accident            I-87 - NYS Thruway       Ulster
# 4      2444280          accident                 I-87 Northway     Saratoga
# ...        ...               ...                           ...          ...
# 27803  2571682  earlier incident    I-95 - New England Thruway  Westchester
# 27804  2571695      construction            I-87 - NYS Thruway     Rockland
# 27805  2571700      construction  I-87 Major Deegan Expressway        Bronx
# 27806  2571705          accident            I-87 - NYS Thruway     Rockland
# 27807  2571706      debris spill    I-95 - New England Thruway  Westchester
#
# ...

# %%
event['Event Duration']= event['Close Time'] - event['Create Time']
event.head()
# Out:
#         ID Event Type       Facility Name    County State         Create Time  \
# 0  2444268   incident                I-80   Passaic    NJ 2019-01-01 10:28:48
# 1  2444269   accident  I-87 - NYS Thruway    Orange    NY 2019-01-01 10:47:49
# 2  2444270   accident               I-495   Suffolk    NY 2019-01-01 13:07:46
# 3  2444273   accident  I-87 - NYS Thruway    Ulster    NY 2019-01-01 14:50:46
# 4  2444280   accident       I-87 Northway  Saratoga    NY 2019-01-01 17:11:46
#
#            Close Time   Latitude  Longitude  Event Duration
# 0 2019-01-01 10:31:45  40.905799 -74.161079 0 days 00:02:57
# 1 2019-01-01 11:09:05  41.691460 -74.078010 0 days 00:21:16
# 2 2019-01-01 14:02:49  40.818401 -73.063697 0 days 00:55:03
# 3 2019-01-01 16:32:56  42.013360 -73.998992 0 days 01:42:10
# 4 2019-01-01 18:25:44  42.816600 -73.766899 0 days 01:13:58

# %%
event['month']= pd.DatetimeIndex(event['Create Time']).month
event.head()
# Out:
#         ID Event Type       Facility Name    County State         Create Time  \
# 0  2444268   incident                I-80   Passaic    NJ 2019-01-01 10:28:48
# 1  2444269   accident  I-87 - NYS Thruway    Orange    NY 2019-01-01 10:47:49
# 2  2444270   accident               I-495   Suffolk    NY 2019-01-01 13:07:46
# 3  2444273   accident  I-87 - NYS Thruway    Ulster    NY 2019-01-01 14:50:46
# 4  2444280   accident       I-87 Northway  Saratoga    NY 2019-01-01 17:11:46
#
#            Close Time   Latitude  Longitude  Event Duration  month
# 0 2019-01-01 10:31:45  40.905799 -74.161079 0 days 00:02:57      1
# 1 2019-01-01 11:09:05  41.691460 -74.078010 0 days 00:21:16      1
# 2 2019-01-01 14:02:49  40.818401 -73.063697 0 days 00:55:03      1
# 3 2019-01-01 16:32:56  42.013360 -73.998992 0 days 01:42:10      1
# 4 2019-01-01 18:25:44  42.816600 -73.766899 0 days 01:13:58      1

# %%
import numpy as np

# %%
month_d=month_df.reset_index()
month_d=month_d.rename(columns = {'index':'Month','month':'count'})
month_d.head()
# Out:
#    Month  count
# 0      7   5312
# 1      8   5284
# 2      9   5159
# 3      1   4690
# 4      3   4217

# %%
max_val=month_d['count'].max()
month_d.loc[month_d['count']==max_val, 'Month'].item()
# Out:
# 7

# %%
month_d.plot.bar(x='Month' , y= 'count',xlabel='Month', ylabel='Event count',title='Month vs Event Count')
# Out:
# <AxesSubplot:title={'center':'Month vs Event Count'}, xlabel='Month', ylabel='Event count'>

# %%
month_d.to_csv('Ques5.csv')

# %%
strings=list(map(lambda x: x.startswith('accident'), event['Event Type'] ))
strings
# Out:
# [False,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  True,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  True,
#  True,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  True,
#  False,
#  True,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  False,
# ...

# %%
Type = []
for i in range(len(strings)):
    if strings[i]==True:
        Type.append(event['Event Type'][i])

# %%
Type=set(Type)
pd.DataFrame(Type, columns=['Event Type'])
# Out:
#                                            Event Type
# 0   accident with property damage, overheight trac...
# 1                              accident, hazmat spill
# 2                                accident road closed
# 3                                  accident, flooding
# 4                            accident, disabled truck
# 5          accident with property damage, fluid spill
# 6                accident investigation, vehicle fire
# 7                        accident, overturned vehicle
# 8         accident investigation, pedestrian accident
# 9     accident investigation, vehicle off the roadway
# 10  accident investigation, police department acti...
# 11                              accident, downed tree
# 12  accident with injuries, overturned tractor tra...
# 13                             accident, debris spill
# 14  accident investigation, fuel spill, jack-knife...
# 15                         accident, disabled vehicle
# ...
